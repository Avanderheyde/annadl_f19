# %% [markdown]
# # Week 5: Recurrent neural networks
#
# Text, speech, weather, sensor output and video are but a few examples of the many types of data that is inherently sequential. So how does one predict the next word in a sentence, future temperatures or missing video frames? Using **recurrent neural networks** (RNNs)!

# %%
# %matplotlib inline

import numpy as np
import random
import sys
import io
from bs4 import BeautifulSoup
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Exercises

# %% [markdown]
# #### Modeling text

# %% [markdown]
# Text prediction is a good place to start when learning about RNNs, because most of us humans have a pretty well
# optimized inner model for text prediction ourselves. We can, therefore, easily assess the performance of a neural
# network in executing this task.
#
# Below is some code that loads the screenplay for Tarantino's 1994 film 'Pulp Fiction'. I recommend reading through the
# first 20 lines or so to get a feeling for the language and style used (and enjoy probably the best written screenplay
# in the history of film).

# %%
import requests as rq

response = rq.get("http://www.dailyscript.com/scripts/pulp_fiction.html")
pulpfiction = BeautifulSoup(response.content, "html.parser").getText()
text = BeautifulSoup(response.content, "html.parser").getText()
print(pulpfiction[:2000])
# Out:
# "PULP FICTION" -- by Quentin Tarantino & Roger Avary
#
#
#                                       "PULP FICTION"
#
#                                             By
#
#                              Quentin Tarantino & Roger Avary
#
#
#
#                PULP [pulp] n.
#
#                1. A soft, moist, shapeless mass or matter.
#
#                2. A magazine or book containing lurid subject matter and
#                being characteristically printed on rough, unfinished paper.
#
#                American Heritage Dictionary: New College Edition
#
#                INT. COFFEE SHOP – MORNING
#
#                A normal Denny's, Spires-like coffee shop in Los Angeles.
#                It's about 9:00 in the morning. While the place isn't jammed,
#                there's a healthy number of people drinking coffee, munching
#                on bacon and eating eggs.
#
#                Two of these people are a YOUNG MAN and a YOUNG WOMAN. The
#                Young Man has a slight working-class English accent and,
#                like his fellow countryman, smokes cigarettes like they're
#                going out of style.
#
#                It is impossible to tell where the Young Woman is from or
#                how old she is; everything she does contradicts something
#                she did. The boy and girl sit in a booth. Their dialogue is
#                to be said in a rapid pace "HIS GIRL FRIDAY" fashion.
#
#                                      YOUNG MAN
#                          No, forget it, it's too risky. I'm
#                          through doin' that shit.
#
#                                      YOUNG WOMAN
#                          You always say that, the same thing
#                          every time: never again, I'm through,
#                          too dangerous.
#
#                                      YOUNG MAN
#                          I know that's what I always say. I'm
#                          always right too, but –

# %% [markdown]
# > **Ex. 5.1.1:** What is the most used symbol in this screenplay and what accuracy would a model constantly predicting this symbol obtain? In other words, what is the "baseline accuracy"?

# %%
freq = {}

for i in text:
    if i in freq:
        freq[i]+=1
    else:
        freq[i]=1

print("Counts of symbols")
print(freq)
max(freq, key=freq.get)

print("Baseline Accuracy is: %f" % (freq[' ']/len(text)))
# Out:
# Counts of symbols
# {'\n': 7602, '"': 206, 'P': 310, 'U': 694, 'L': 793, ' ': 164787, 'F': 337, 'I': 1757, 'C': 775, 'T': 1418, 'O': 762, 'N': 1598, '-': 184, 'b': 1629, 'y': 2212, 'Q': 19, 'u': 3530, 'e': 11513, 'n': 7182, 't': 9211, 'i': 6751, 'a': 7713, 'r': 5013, 'o': 8344, '&': 5, 'R': 538, 'g': 2341, 'A': 1081, 'v': 703, '\r': 7596, 'B': 755, '[': 1, 'p': 1568, 'l': 4033, ']': 1, '.': 2806, '1': 23, 's': 6413, 'f': 1913, ',': 1601, 'm': 2322, 'h': 6163, '2': 19, 'z': 67, 'k': 1596, 'c': 2595, 'd': 3507, 'j': 126, 'H': 656, 'D': 435, ':': 103, 'w': 1982, 'E': 1510, 'S': 987, '–': 218, 'M': 885, 'G': 368, "'": 1623, '9': 10, '0': 21, 'W': 556, 'Y': 408, ';': 2, '?': 453, '(': 236, ')': 236, 'q': 64, '!': 178, 'K': 131, 'V': 560, 'J': 480, 'x': 145, '3': 9, '7': 11, '4': 20, '5': 30, 'X': 42, '/': 18, '6': 6, 'Z': 56, '#': 8, '8': 3, '%': 1}
# Baseline Accuracy is: 0.541059

# %% [markdown]
# I've adapted some code for text generation from [this Keras example](https://keras.io/examples/lstm_text_generation/).
# I've inserted some questions in the code (look for `Q:`) for you to answer in the exercise below.

# %%
# Q1: What is the purpose of this block? When is `char_indices` used? What about `indices_char`?
chars = sorted(list(set(text)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# Q2: What is the purpose of this block? What does the `seqlen` and `step` parameters do?
seqlen = 40
step = seqlen
sentences = []
for i in range(0, len(text) - seqlen - 1, step):
    sentences.append(text[i: i + seqlen + 1])

# Q3: What about this block? What is `x` and what is `y`? Why do they have this dimensionality?
x = np.zeros((len(sentences), seqlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), seqlen, len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    # Q3a: What happens in this loop?
    for t, (char_in, char_out) in enumerate(zip(sentence[:-1], sentence[1:])):
        x[i, t, char_indices[char_in]] = 1
        y[i, t, char_indices[char_out]] = 1


# Q4: Here we build the model. What does the `return_sequences` argument do? Why the dense layer at the end?
model = Sequential()
model.add(LSTM(128, input_shape=(seqlen, len(chars)), return_sequences=True))
model.add(Dense(len(chars), activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(learning_rate=0.01),
    metrics=['categorical_crossentropy', 'accuracy']
)

def sample(preds, temperature=1.0):
    """Helper function to sample an index from a probability array."""
    preds = np.asarray(preds).astype('float64')
    preds = np.exp(np.log(preds) / temperature)  # softmax
    preds = preds / np.sum(preds)                #
    probas = np.random.multinomial(1, preds, 1)  # sample index
    return np.argmax(probas)                     #


def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text."""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - seqlen - 1)
    
    # Q5: What does diversity do?
    for diversity in [0.2, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + seqlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, seqlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
            
            # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
            preds = model.predict(x_pred, verbose=0)
            next_index = sample(preds[0, -1], diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=50,
          callbacks=[print_callback])
# Out:
# WARNING:tensorflow:From //anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/50
# 7614/7614 [==============================] - 8s 993us/step - loss: 2.2655 - categorical_crossentropy: 2.2655 - accuracy: 0.5356
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "chicken. But you
#                      "
# chicken. But you
#
# ----- diversity: 0.5
# ----- Generating with seed: "chicken. But you
#                      "
# chicken. But you
#
# ----- diversity: 1.0
# ----- Generating with seed: "chicken. But you
#                      "
# chicken. But you
#                        oorxtwgtaca tout
#
#     V  Ye    Vhe nt  y  Amo
#
# eos      (-ntyI9d   w u e.
#  I SWv r,u 2oa torkmsfert E ouvs      a       oungintondbawnckethrfns fhlr /
# nhheNgnkgentnnn humt
# v        J baur
# 'JZeOqtoifn b topemab ahetnn.acsspungtmysh 'ri
#
#  hey MWO k
#         dtols .
#                   o, wk,Wdostkssefny  cfncrruwt mvrdntpubou
#                       patctL pminmtXy
#
# n      Iu
# Epoch 2/50
# 7614/7614 [==============================] - 7s 956us/step - loss: 1.4516 - categorical_crossentropy: 1.4516 - accuracy: 0.6278
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: " that mean?
#
#                          "
#  that mean?
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " that mean?
#
#                          "
#  that mean?
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " that mean?
#
#                          "
#  that mean?
#
#                           tha Sav thin som                                                           BOL)
#                               SP tientyomakprd shaer lovhes.
# f You's t ma .TON
#                                          Is the
#              The dong he bs sror kine  n                                                                  LOESS LOLMSS. MMDINCERNCE
#
#
# Epoch 3/50
# 7614/7614 [==============================] - 7s 933us/step - loss: 1.2181 - categorical_crossentropy: 1.2181 - accuracy: 0.6765
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "ly appreciated.
#
#                      "
# ly appreciated.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ly appreciated.
#
#                      "
# ly appreciated.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ly appreciated.
#
#                      "
# ly appreciated.
#
#                                          Nw your you'ty But we
#        dit't get)
#                                                              do thit syttig te sfrots
#                                       (intrered fhe dot the il to  wot I wasm to theik wo gourle whirg in dow, med wow up bet wich sin?
#
#                                                 the thaplys, buckesperlhit pow on
#                    on thes
# Epoch 4/50
# 7614/7614 [==============================] - 8s 1ms/step - loss: 1.1072 - categorical_crossentropy: 1.1072 - accuracy: 0.7042
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "               I don't want to be a burd"
#                I don't want to be a burd a man a man a can a stare the car a men a take a stires the the the fing the right the the the the from the the the store the of her in the reat the the take a talk a
#
# ----- diversity: 0.5
# ----- Generating with seed: "               I don't want to be a burd"
#                I don't want to be a burds
#                                                                         VINCENT
#                                                                                                                                bit in the fach a gan a can a canta don't
#
# ----- diversity: 1.0
# ----- Generating with seed: "               I don't want to be a burd"
#                I don't want to be a burdy..
#
#          me takine abe the byead, wang isting wish s drAh, thit iem Maning it're's coulla
#                   fare is? Ho –
#                                                    VINCENT
#                     pinns bloake in?
#
#                                   JULES
#                                  goles bachnes liot it'c we sere and duss .41 177. hanp ceer to           Malfe, and it the pa
# Epoch 5/50
# 7614/7614 [==============================] - 7s 907us/step - loss: 1.0387 - categorical_crossentropy: 1.0387 - accuracy: 0.7207
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "A. remain firmly fixed on the –
#
#      "
# A. remain firmly fixed on the –
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "A. remain firmly fixed on the –
#
#      "
# A. remain firmly fixed on the –
#
# ----- diversity: 1.0
# ----- Generating with seed: "A. remain firmly fixed on the –
#
#      "
# A. remain firmly fixed on the –
#
#                         Butch to to she shot, Maminn Wilf, she?
#
#                                                       f here ho stle he pearf ess from go doll olka?
#
#                       into itte – inchop, to stockin)
#                                                  mands oof think of the tanc omxy tho ge
#
#                   Limpall LLICS RATKE- – VINCELD"" OOOM – SAIN IWHTCEN (AT:
#
#
# Epoch 6/50
# 7614/7614 [==============================] - 7s 901us/step - loss: 0.9888 - categorical_crossentropy: 0.9888 - accuracy: 0.7329
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "               Butch.  They keep underes"
#                Butch.  They keep underes a betwer and
#
# ----- diversity: 0.5
# ----- Generating with seed: "               Butch.  They keep underes"
#                Butch.  They keep underest in the finger with word his pissed to the baght of his ben like a
#
# ----- diversity: 1.0
# ----- Generating with seed: "               Butch.  They keep underes"
#                Butch.  They keep underesheldy like it.
#
#              Buterlus outster. Here and piloshinc?
#
#              THE WOLF
#                Bitht stalledly hif  ave hourker, I'm on all tayneg
#       THE WULP ST-FITM.
#
#            Hell STRET B1K
#
#                      Ged it?
#
#                        as the putches but (fow etorfeat mode. The
#                He's dead is to taster SVINCENG vig. Offeee, Jules'
#
# Epoch 7/50
# 7614/7614 [==============================] - 7s 922us/step - loss: 0.9487 - categorical_crossentropy: 0.9487 - accuracy: 0.7427
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "                you could ever do would "
#                 you could ever do would story his head:
#
# ----- diversity: 0.5
# ----- Generating with seed: "                you could ever do would "
#                 you could ever do would Butch hands in
#
# ----- diversity: 1.0
# ----- Generating with seed: "                you could ever do would "
#                 you could ever do would prighes my freet, is congere
#                        frout
#                                    off.
#
#                                                                       Are happen, you just it'll like it.
#
#              To                      BUTCHT
#                                      neppluss.
#
#                                              VINCENT
#                                  hand
# Epoch 8/50
# 7614/7614 [==============================] - 7s 910us/step - loss: 0.9161 - categorical_crossentropy: 0.9161 - accuracy: 0.7502
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "            VINCENT
#                    "
#             VINCENT
#
# ----- diversity: 0.5
# ----- Generating with seed: "            VINCENT
#                    "
#             VINCENT
#
# ----- diversity: 1.0
# ----- Generating with seed: "            VINCENT
#                    "
#             VINCENT
#                              passed towatiens at a phite?
#
#                                        JULES
#                                     VINCENT
#                                         righticall and be whreat, Londo!
#                               e isty does Jotty. But what Landard to
#                                    way?
#
#                                                         VINCENT
#
# Epoch 9/50
# 7614/7614 [==============================] - 7s 931us/step - loss: 0.8899 - categorical_crossentropy: 0.8899 - accuracy: 0.7569
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "ead: "yes."
#
#                          "
# ead: "yes."
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ead: "yes."
#
#                          "
# ead: "yes."
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ead: "yes."
#
#                          "
# ead: "yes."
#
#                                      sabta finder, I take never did aid table sike,
#                    k you get gies upant appenting Back, on the
#                  pregays lifor it to your drink conteation
#                            So seetch nexg)
#                    yourrone)
#                  yallard. Anh'ch nods, he's cotressees. BUTCH'
#                            FABIENNE
#                            They down'
# Epoch 10/50
# 7614/7614 [==============================] - 7s 925us/step - loss: 0.8656 - categorical_crossentropy: 0.8656 - accuracy: 0.7622
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "s Vincent.
#
#                           "
# s Vincent.
#
# ----- diversity: 0.5
# ----- Generating with seed: "s Vincent.
#
#                           "
# s Vincent.
#
#                                                                                                                                                                                                                                                                                                    JULES
#                                                                                       BUTCH
#
# ----- diversity: 1.0
# ----- Generating with seed: "s Vincent.
#
#                           "
# s Vincent.
#
#                                        quilk.
#
#                a drinking to him.!ONG room.
#
#                To notr deat, wains Joum in.
#
#                Hi. Pom Marselluse kill.
#
#                                Vincent cofficalter.
#
#              Lit's ready of  Now, I'll and which heads seach out through
#                an overais. That my us. The Mia. We know when the back Anoall the call he hear dress, is Vincen
# Epoch 11/50
# 7614/7614 [==============================] - 7s 900us/step - loss: 0.8409 - categorical_crossentropy: 0.8409 - accuracy: 0.7676
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "             JULES
#                     "
#              JULES
#
# ----- diversity: 0.5
# ----- Generating with seed: "             JULES
#                     "
#              JULES
#
# ----- diversity: 1.0
# ----- Generating with seed: "             JULES
#                     "
#              JULES
#                          Seamirys down to the know what do we Cangise
#                                If you blees)
#                                    YOUNG WOMAN
#                          Evily head of the gods to the room. Three
#                                    collin' is you we dollame to go the shot itsel, and blanges go inside to the poor in that
#                                               MARSELLUS
#
# Epoch 12/50
# 7614/7614 [==============================] - 7s 911us/step - loss: 0.8218 - categorical_crossentropy: 0.8218 - accuracy: 0.7716
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "the scenario by the two men's
#         "
# the scenario by the two men's
#
# ----- diversity: 0.5
# ----- Generating with seed: "the scenario by the two men's
#         "
# the scenario by the two men's
#                                                                                                                                                                                                                    YOUNG WOMAN
#
# ----- diversity: 1.0
# ----- Generating with seed: "the scenario by the two men's
#         "
# the scenario by the two men's
#                          to by up to stick with she robea, from the ZOOSTE "The
#                back.
#
#                                                    Sanitrostiable buse in the curlem has ligstincelth I do what
#                mance-lice looks to Vincent! You feal handbane here S VING THE WALIACE'S –
#
#                                         INT. APPINT BROOMS
#
#
# Epoch 13/50
# 7614/7614 [==============================] - 7s 939us/step - loss: 0.8060 - categorical_crossentropy: 0.8060 - accuracy: 0.7754
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "much shit this
#                        "
# much shit this
#                          What the putche fine the find me and his
#                          the pookersting the door and stares and
#                          What do you do the two men the face
#                          the father's a fight the find me a see
#                          I don't know what I do at his hands of
#                          the putche the fight a fight the fuck do it a
#
# ----- diversity: 0.5
# ----- Generating with seed: "much shit this
#                        "
# much shit this
#                          FABIENNE
#                          When you mean a still with the door.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "much shit this
#                        "
# much shit this
#                          read otherfucker to go!
#
#                                  Thut?
#
#                                      woor?
#
#                                      good, I didn't no, no, no... remail a boot is a
#               Alea.
#
#                the drippated peedipet, had a ract up by.
#
#                                               BRETT
#                          I'm goen't go to now wathin' you on
# Epoch 14/50
# 7614/7614 [==============================] - 7s 947us/step - loss: 0.7913 - categorical_crossentropy: 0.7913 - accuracy: 0.7794
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "          of his pawnshop when, all of a"
#           of his pawnshop when, all of a show the
#                          the stop the street. What does the
#                          the store heard is the bathroom to the
#                          the store his head: "yes."
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "          of his pawnshop when, all of a"
#           of his pawnshop when, all of a sasse
#                          the but the room.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "          of his pawnshop when, all of a"
#           of his pawnshop when, all of a wall was ain't every
#                          dripod's meaning from the outtidion out
#                          in said is going fuckin' assed Sody.
#
#                                                JULIS
#                          I'll let's gotta mouthin There!
#
#                The PABORTS OF, aby The tird with the gudvers. The P4OWONY fist bag claigs her
#                          don't fai
# Epoch 15/50
# 7614/7614 [==============================] - 7s 912us/step - loss: 0.7780 - categorical_crossentropy: 0.7780 - accuracy: 0.7824
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "o
#                          believe Mar"
# o
#                          believe Marsellus the car in the bad for the
#                          you need a counter and she cassed is a smart of the
#                          a robbery and the street was a shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "o
#                          believe Mar"
# o
#                          believe Marsellus to all the Chees on the man a mave to be and
#                          I don't know what we noumal toss is the sinute
#                          is starts like a wast an ardard – this shots and
#
# ----- diversity: 1.0
# ----- Generating with seed: "o
#                          believe Mar"
# o
#                          believe Marvel all the handle was untty... did on hall somethin' a has
#                          massage you bust Bxinds over in his away, Vincent, scear
#                stems mind of his stay all fills the mart you tyarted. .olla need-
#                 that house, now looking arougl dillionnog.
#
#                                        OWh isnte worl war new, leading down mean is are you thought I woulda
# Epoch 16/50
# 7614/7614 [==============================] - 7s 914us/step - loss: 0.7666 - categorical_crossentropy: 0.7666 - accuracy: 0.7856
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: ".
#
#                Vincent freezes.
#
# "
# .
#
#                Vincent freezes.
#
#                                      I'm the bag inside, the bag in the bag in the back.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: ".
#
#                Vincent freezes.
#
# "
# .
#
#                Vincent freezes.
#
#                                                                                                                                                                                                                                                                                                                                                               I was a couple down one anybody.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: ".
#
#                Vincent freezes.
#
# "
# .
#
#                Vincent freezes.
#
#                                      then Judcy in or outticung we're you're
#                          your.
#
#                                      don't you?
#
#                                      Onne's outsage, lyippet if you fuckin' bad,
#                          just when you fash.
#
#                                      My name up.
#
#                                      ESMARELDA
#
# Epoch 17/50
# 7614/7614 [==============================] - 7s 910us/step - loss: 0.7553 - categorical_crossentropy: 0.7553 - accuracy: 0.7890
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "       VINCENT
#                         "
#        VINCENT
#
# ----- diversity: 0.5
# ----- Generating with seed: "       VINCENT
#                         "
#        VINCENT
#                          So a good bighting to go.
#
#                                                                                                                                                                VINCENT
#
# ----- diversity: 1.0
# ----- Generating with seed: "       VINCENT
#                         "
#        VINCENT
#                          Butch goaba gozes the hole worme.
#                                      oolthouckent.
#
#                                       LIN (O.S.)
#                          You shore it to know what I'm mox you winder like hald.
#                here, just say fring right.
#
#                Butch's hand do train for the morniom. Afcent. He rips in
#                          lighter with about –
#
#
# Epoch 18/50
# 7614/7614 [==============================] - 7s 905us/step - loss: 0.7460 - categorical_crossentropy: 0.7460 - accuracy: 0.7910
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "k at him, spaced-out.
#
#                "
# k at him, spaced-out.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "k at him, spaced-out.
#
#                "
# k at him, spaced-out.
#
#                                                                                                                                                                                                                   BUTCH
#                          What the stante to brain everybody pronder thoie
#                          out the bad.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "k at him, spaced-out.
#
#                "
# k at him, spaced-out.
#
#                His come is a man I chark appine)
#                          Poot.
#
#                                       do your asts doent like!
#
#                Butch rececpinues into the counter, 'm two lemen, the Fourth anow
#                          only verving peoply 'im into making at
#                          outlome shippere that's imsees a tame Twry.
#
#                EXT. BACENTOPEN- FFFFVIENCE V
# Epoch 19/50
# 7614/7614 [==============================] - 7s 955us/step - loss: 0.7371 - categorical_crossentropy: 0.7371 - accuracy: 0.7933
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "e girl. The
#                          p"
# e girl. The
#                          parked and sits and the rest of the all the same
#                          of her feel a right.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "e girl. The
#                          p"
# e girl. The
#                          panchoor, and the morning. She seem
#                          the seen a baby, I'll gonna be back into the
#                          What does his head: "Yes."
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "e girl. The
#                          p"
# e girl. The
#                          playbald of "Crunse father, the guns out of her tooush mirror
#                          tell timary.
#
#                                      We ad your cafficen Lousealdly and Jules for a toard of a hund and
#                          Why he chairget.
#
#                                      it obht of years. Butch Dangges her a man fills or
#                breffiat in the life.
#
#
# Epoch 20/50
# 7614/7614 [==============================] - 7s 979us/step - loss: 0.7292 - categorical_crossentropy: 0.7292 - accuracy: 0.7952
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "ncent. Marsellus
#                      "
# ncent. Marsellus
#                          the bag before in his hand with a
#                          the bag in the man and start on the
#                          the bag.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ncent. Marsellus
#                      "
# ncent. Marsellus
#                          a way the alley in the shot of the
#                          not the ment of his hand and starting a
#                          Will he witn a battle and like it and
#                          could be a car playel man, I got a celles the nother
#                          the front of a bront of a right
#                          the two estair and little nime hand of
#
# ----- diversity: 1.0
# ----- Generating with seed: "ncent. Marsellus
#                      "
# ncent. Marsellus
#                          go. The bar they.
#
#                Jules ross? I hands parted his larse.
#
#                Mia's gon'                      I'm hims, the door as it and a
#                          she clufficel man, I hand wide with a lut bag ballpent of the wait and Butch toom. He about
#                          YOUNG WOMAN
#                          rong your ass here.
#
#
# Epoch 21/50
# 7614/7614 [==============================] - 7s 928us/step - loss: 0.7218 - categorical_crossentropy: 0.7218 - accuracy: 0.7972
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "              on that invention they sho"
#               on that invention they shot to the
#                          of been shit the table.
#
#                                      I'm takin' me a lot of like a secent.
#
#                                      I'm gonna be with the morning. It's
#                          the parses the door out the table.
#
#                                      What the starter watch of you something
#                          the parses the do
# ----- diversity: 0.5
# ----- Generating with seed: "              on that invention they sho"
#               on that invention they should this shit in the pants the
#                          pain, never have the fingers. The door a killet.
#
#                                      I'm tell you take has a cop of his body
#                                                                                                                                                          JULES
#                          She takes a shart her neve
# ----- diversity: 1.0
# ----- Generating with seed: "              on that invention they sho"
#               on that invention they shows has been black
#                          you Fabyea-ya)be guy itnederyip, on
#                          if it. Encepty apper.
#
#                          He let of you the p'ce table.
#
#                Jules laggl strase.
#
#                Maynexcated you do that?
#
#                                            I'm gonna do. That take Butch.
#
#                                      when you's not
# Epoch 22/50
# 7614/7614 [==============================] - 7s 974us/step - loss: 0.7144 - categorical_crossentropy: 0.7144 - accuracy: 0.7989
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "  VINCENT
#                          Did "
#   VINCENT
#                          Did you do when I did.
#
#                                      I don't know what the shows the shows a
#                          the show the door.
#
#                                      I don't know what the story stands on
#                          the show the shows the shows on the bag man is
#                          of the man ass out the man as the shows
#                          the shows
# ----- diversity: 0.5
# ----- Generating with seed: "  VINCENT
#                          Did "
#   VINCENT
#                          Did you a men the mance in the motherfucker is
#                          put on the name ass. I didn't a man
#                          of a table with a big comes the bedroom of the
#                          this shit.
#
#                                      The bag ready, his eyes off the bathroom on
#                          the shouge she floor.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "  VINCENT
#                          Did "
#   VINCENT
#                          Did you give 'e spouge normally mansed and
#                          ol arien his head: "Yes."
#
#                                      Legitald to see if the doors two in there nevor heart,
#                          plays down to athing at PumprEst. I don't take to we of coffee.
#
#                                      THE WOLF
#                          The Hoydies. Pigs WIMNSSCOUD NO.S.)
#
# Epoch 23/50
# 7614/7614 [==============================] - 8s 994us/step - loss: 0.7090 - categorical_crossentropy: 0.7090 - accuracy: 0.8007
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "cal type?
#                              "
# cal type?
#
# ----- diversity: 0.5
# ----- Generating with seed: "cal type?
#                              "
# cal type?
#
# ----- diversity: 1.0
# ----- Generating with seed: "cal type?
#                              "
# cal type?
#                                             MAYNARD
#                            I'm talkin' fame.
#
#                LACT iE drive one remember.
#
#                Goddnames table SLOPING, a completrin'
#                          takes has inead.
#
#                Ze my first way.
#
#                                              If I'm take to know, as move on who he
#                Ancould of Jules' from the hell.
#
#
# Epoch 24/50
# 7614/7614 [==============================] - 7s 952us/step - loss: 0.7018 - categorical_crossentropy: 0.7018 - accuracy: 0.8024
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "         What's a pilot?
#
#             "
#          What's a pilot?
#                                      MAYNARD
#                          They pookin' thing with the story to
#                          the made of the parts and takes a sitting at the morning. What does it
#                          the big back and doing up and with the
#                          place wall the mades and the bathroom door a both
#                          the bag in the mades of the parts an
# ----- diversity: 0.5
# ----- Generating with seed: "         What's a pilot?
#
#             "
#          What's a pilot?
#
#                                      JULES
#                          Shoply hear on the stor. I didn't make
#                          the pancher. Butch reads and the boy-like a bittor parts for a lot
#                          is a seching up the motherfucker and
#                          the borrotic. This is Butch tee-shirt.
#
#                                      It's gonna tell what I want you to
#
# ----- diversity: 1.0
# ----- Generating with seed: "         What's a pilot?
#
#             "
#          What's a pilot?
#
#                                      THE WOLF
#                          Inwall really wall?
#                          Vincent and Lance bring up to get staling in
#                          munging who's in the booth. The pethung.
#                is town her jugh, is being face hid.
#
#                                      JULES
#                          A tonght you, I'll there calling to brands.
#
#
# Epoch 25/50
# 7614/7614 [==============================] - 7s 952us/step - loss: 0.6973 - categorical_crossentropy: 0.6973 - accuracy: 0.8031
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "is bent over a wooden
#                h"
# is bent over a wooden
#                him.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "is bent over a wooden
#                h"
# is bent over a wooden
#                his fight my little want to gun has take in
#                          that called.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "is bent over a wooden
#                h"
# is bent over a wooden
#                here staries on him, resides)
#                          Park: "RiAIT."
#
#                Riser?
#
#                                         A some room and ghesting to scar.
#
#                                      Vance CHOR his get of cool. Do I
#                in a big Godl.
#
#                                     VINCENT
#                          Sits.
#
#                INT. AGARTMENT JULWIS it a
# Epoch 26/50
# 7614/7614 [==============================] - 7s 960us/step - loss: 0.6915 - categorical_crossentropy: 0.6915 - accuracy: 0.8050
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "  now I'm definitely not gonna tell
#   "
#   now I'm definitely not gonna tell
#                          the bathroom the street. The booth masse in the
#                          the bathroom to the back of the bathroom of the
#                          the back to the bathroom the bathroom of the
#                          the bag.
#
#                                      I'm to go of fight your finder to
#                          the shot. The motherfucker in the morning to
# ----- diversity: 0.5
# ----- Generating with seed: "  now I'm definitely not gonna tell
#   "
#   now I'm definitely not gonna tell
#                          the table.
# ----- diversity: 1.0
# ----- Generating with seed: "  now I'm definitely not gonna tell
#   "
#   now I'm definitely not gonna tell
#                          continue the will with the larsest right the mirror:
#
#                                      No, I're go bocksher.
#
#                On the other, he'su is stoots up it, then all to two.
#
#                                      Ansering – bit it's a fat me!
#
#                                      RED A voing nit, Bret
#                          of mumbed letsed me, this, Hone
# Epoch 27/50
# 7614/7614 [==============================] - 7s 967us/step - loss: 0.6874 - categorical_crossentropy: 0.6874 - accuracy: 0.8059
#
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: "'s a great
#                          bo"
# 's a great
#                          boxing the shower the shower the shit in
#                          the show the show the show. The pook on the
#
# ----- diversity: 0.5
# ----- Generating with seed: "'s a great
#                          bo"
# 's a great
#                          body, I can han who has the morning. What
#                          is the name is before is the room, strilf
#                          is it's a fifthin' you a bunch of
#                               (to Mia)
#                          You mind that shake than kick. The two
#
# ----- diversity: 1.0
# ----- Generating with seed: "'s a great
#                          bo"
# 's a great
#                          bossn Butch what happens checking driving.
#
#                              Vincent erosy and watch eyes the light the
#                In'louse threw...
#
#                                                       As JIMMIE TE OLF
#
#                          YOUNG MANADE.
#                          I never to Pruliabon
#                holding that in her head it. I'm all
#                to 'ilma be ofe
# Epoch 28/50
# 7614/7614 [==============================] - 7s 943us/step - loss: 0.6829 - categorical_crossentropy: 0.6829 - accuracy: 0.8077
#
# ----- Generating text after Epoch: 27
# ----- diversity: 0.2
# ----- Generating with seed: "he same thing.
#
#                       "
# he same thing.
#
# ...
#
#                                      Anythin' dadybroan.
#
#                LAIT, she giveng my normal and car, much so?
#
#                                      VINCENT
#                          Vincent takes a splites the rapiol?
#
#
# Epoch 42/50
# 7614/7614 [==============================] - 8s 1ms/step - loss: 0.6450 - categorical_crossentropy: 0.6450 - accuracy: 0.8174
#
# ----- Generating text after Epoch: 41
# ----- diversity: 0.2
# ----- Generating with seed: "t?
#
#                                   "
# t?
#
#                                      FABIENNE
#                          What doesn't mouth of the fuckin' see-ligh
#                          to be Jody steaked you should this little
#                          the same thing. We see the table.
# ----- diversity: 0.5
# ----- Generating with seed: "t?
#
#                                   "
# t?
#
#                                                                       JULES
#                          What to expect Amsterder that mean you
#                          the seckin' for a mills, the both of the other, the
#                               (to Brett)
#                          I don't use to me. Whole he they call
#                          and I'm the wife. The both man they down how
#                          this shi
# ----- diversity: 1.0
# ----- Generating with seed: "t?
#
#                                   "
# t?
#
#                                      VINCENT
#                          I wake.
#
#                The Wolf still branges in Vincent,
#                          good take you, My. tectious look or somethin' at if me a foot massage. Vinceld you
#                          stow.
#
#                EXT. PTPELDS in her was that most. Mia low
#                accord to him.
#
#                EXT. BEDACAUD OF the ground to lesp to tmed!
#
#
# Epoch 43/50
# 7614/7614 [==============================] - 7s 933us/step - loss: 0.6430 - categorical_crossentropy: 0.6430 - accuracy: 0.8171
#
# ----- Generating text after Epoch: 42
# ----- diversity: 0.2
# ----- Generating with seed: "ide from how it looks, the car's
#      "
# ide from how it looks, the car's
#                          the same was your fuckin' do.
#
#                                      VINCENT
#                          You were starting to go of the fuck did a tasty mouth with a porter
#                          the way it to the ready in the fronting at the fuckin' seckin' a table want to the floor.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ide from how it looks, the car's
#      "
# ide from how it looks, the car's
#                          readies as that right now... be fuckin'
#                          don't didn't mean the nice, worked, a ture a dure. The door of
#                          lot of the watch. The store.
#
#                                      JULES
#                          What's a gucbold 'em. She still parker of
#                          what now wait for back to the table every.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ide from how it looks, the car's
#      "
# ide from how it looks, the car's
#                          said LAN Matzin's get sunfes from
#                          we're know: me into the table
#                          Wautured at him.
#
#                                      Zed's Terapper."
#
#                                      VINCENT
#                          Ueve. I woulda sello, waitry.
#
#                                          VINCENT
#                          My nam
# Epoch 44/50
# 7614/7614 [==============================] - 7s 906us/step - loss: 0.6412 - categorical_crossentropy: 0.6412 - accuracy: 0.8183
#
# ----- Generating text after Epoch: 43
# ----- diversity: 0.2
# ----- Generating with seed: "d sending
#                it up on the "
# d sending
#                it up on the stores. The bathroom the
#                          they call a watch staight.
#
#                                      FABIENNE
#                          I don't tell your assele, too back of
#                          place we got no have some don't
#                          I don't watch.
#
#                                      JULES
#                          I don't give you're that watch.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "d sending
#                it up on the "
# d sending
#                it up on the promoully come hast. The book.
#
#                                      MARSELLUS (O.S.)
#                          I don't eat on from be on a little
#                          of a buight watery Korning in the earth stops off the word.
#
#                                      VINCENT
#                          Yeah, you're gonna give it parts it. And they're
#                          a foot massage
# ----- diversity: 1.0
# ----- Generating with seed: "d sending
#                it up on the "
# d sending
#                it up on the envery: Donya?
#
#                                      Whated a seber goid now I'm of for a mome, unsidd like in
#                          We're typed leeve. But you make all's
#                          on in front of Jod's SGRACKER RIAN
#
#                          Pries throage?
#
#                                      JIMMIE
#                          They keep they're ass behind has?
#
#
# Epoch 45/50
# 7614/7614 [==============================] - 8s 994us/step - loss: 0.6390 - categorical_crossentropy: 0.6390 - accuracy: 0.8177
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: "
#                          Okay gentlemen"
#
#                          Okay gentlemen, we got a second of the
#
# ----- diversity: 0.5
# ----- Generating with seed: "
#                          Okay gentlemen"
#
#                          Okay gentlemen.
#
#                                      VINCENT
#                          I was so far and I'm the life. The
#                                                                                                              VINCENT
#                          Marsellus stand from I Beven'
#                          Hangin' it hands. The towel torry window for
#                          hand in the wal
# ----- diversity: 1.0
# ----- Generating with seed: "
#                          Okay gentlemen"
#
#                          Okay gentlemen, we're bebat is Borbin sloodes ont's the intrink a truple's Taud
#                          to his and that my fast watch oft of the spacker. Now throws the table in scont be
#                          Yolethy fally sure, then... I think you get up,
#                       yel...
#                          too beatwer. I did well happened in the case.
#
#                Vincent takes a pig back lau
# Epoch 46/50
# 7614/7614 [==============================] - 7s 951us/step - loss: 0.6389 - categorical_crossentropy: 0.6389 - accuracy: 0.8190
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: "fect on the world of
#                  "
# fect on the world of
#                          the shot.
#
#                                      JULES
#                          What did I want you to go in the
#                          to your drink this situation: "The door' it
#                          the shot was a big is from the street.
#
#                                      BUTCH
#                          What does the Chenies and starts up the street.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "fect on the world of
#                  "
# fect on the world of
#                          to you.
#
#                                      BUTCH
#                          We should be fuckin' do it has be one of his
#                          staring straight.                     JULES
#                          We should be fighter's light!  Whee sods out of this
#                          say, SPAKYDREAS. The encent of you
#                          to you.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "fect on the world of
#                  "
# fect on the world of
#                                    that, it was a man't coming and servi...was covialin' bedroam.
#
#                Jody closences, his back in Lid Butch drink?
#
#                                      JIMMIE
#                          Not into comes her, which go we hows,
#                laggind madrorch Kronnex.
#
#                INT. MARCELLUS' H                 LANCE
#                          WE SIE in the road
# Epoch 47/50
# 7614/7614 [==============================] - 7s 947us/step - loss: 0.6362 - categorical_crossentropy: 0.6362 - accuracy: 0.8192
#
# ----- Generating text after Epoch: 46
# ----- diversity: 0.2
# ----- Generating with seed: "o, and a little baby tomato.
#          "
# o, and a little baby tomato.
#                               (on the shot. The booth.  We street.
#                          Well, you know why do the door the watch when you some don't
#                          who has take it at her head is a money to
#                          man, the shot. The behind him and the
#
# ----- diversity: 0.5
# ----- Generating with seed: "o, and a little baby tomato.
#          "
# o, and a little baby tomato.
#                          Antwan he's not, to blow. In the
#                          Well, you know what the inta tead.
#                          All strike is in the front diskin'
#                          looks at him, to the freakfish looks over a
#                          of his parkes the shower him.
#
#                                      I meant the shot. Then he was three
#
# ----- diversity: 1.0
# ----- Generating with seed: "o, and a little baby tomato.
#          "
# o, and a little baby tomato.
#                          Hello. They be or nobloy. Butch goneanel sits turndy
#                          off the drongt man that in front of the two med
#                on the LOOP from that giving
#                Vince, you'll killey weatifish the readdy hous the frame to men.
#
#                                      What do your fuckin' nomesong, I have
#                          rume begins offer the w
# Epoch 48/50
# 7614/7614 [==============================] - 7s 949us/step - loss: 0.6345 - categorical_crossentropy: 0.6345 - accuracy: 0.8194
#
# ----- Generating text after Epoch: 47
# ----- diversity: 0.2
# ----- Generating with seed: " into the syringe, mixing with the heroi"
#  into the syringe, mixing with the heroin
#                          the show.
#
#                                      VINCENT
#
# ----- diversity: 0.5
# ----- Generating with seed: " into the syringe, mixing with the heroi"
#  into the syringe, mixing with the heroin
#                          motherfucker.
#
#                                      BUTCH
#                          What do you remember and doin' you
#                          there begins at off, both us the way. And there
#                          floot an imphe doesn't seems to colm her front
#                          same shit the body, still shit in front of
#                          moth
# ----- diversity: 1.0
# ----- Generating with seed: " into the syringe, mixing with the heroi"
#  into the syringe, mixing with the heroin show
#                          seas out a wong cuctare dice.
#
#                                      FABIENNE
#                          This aimar about it was than I'll be any liethers
#                          is you're told. Three listen coneres need
#                          cool, no, no, no, no, no, no.
#
#                                      That's what work in the walleted word of the
# Epoch 49/50
# 7614/7614 [==============================] - 7s 948us/step - loss: 0.6332 - categorical_crossentropy: 0.6332 - accuracy: 0.8197
#
# ----- Generating text after Epoch: 48
# ----- diversity: 0.2
# ----- Generating with seed: "   The needle leaves frame, THRUSTING do"
#    The needle leaves frame, THRUSTING doin' a thirty states up to the store
#                          makes into a feath "HI'S RANGHING his head: "yes."
#
#                                      VINCENT
#                          I don't want this shit of the store.
#
#                                      FABIENNE
#                          I don't want this show "TON HE MARCELLUs' out of the store.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "   The needle leaves frame, THRUSTING do"
#    The needle leaves frame, THRUSTING doin' a table car.
#
#                                      FABIENNE
#                          You were fuckin' show the spot of
#                          that's what I telin' tope in your face.
#                          I was a fuckin' about it.
#
#                                      FABIENNE
#                          We shaking a cup of that show "The
#                Mia smiloke is Butch wouldn
# ----- diversity: 1.0
# ----- Generating with seed: "   The needle leaves frame, THRUSTING do"
#    The needle leaves frame, THRUSTING doin' have starts or
#                          possed Cosmor for a sighed whide with him.
#
#                                      BRETT
#                          ED SULLIVAN the walking it me out a goddommbeearya. Mine.
#                She pethurger his bedroom in the watch,
#                          mastack in it.
#
#                EXT. JIMMIE & TOUS – MOT ATTAR COON ROOM – DAY
#
#
# Epoch 50/50
# 7614/7614 [==============================] - 7s 920us/step - loss: 0.6315 - categorical_crossentropy: 0.6315 - accuracy: 0.8205
#
# ----- Generating text after Epoch: 49
# ----- diversity: 0.2
# ----- Generating with seed: "ncent bump fists.
#
#                    "
# ncent bump fists.
#
#                                      VINCENT
#                          I didn't means the door on the man?
#
#                                      VINCENT
#                          I don't know what the hole and shake
#                          the mankin' fallow to say.
#
#                                      FABIENNE
#                               (on the showered to get work as he can't
#
# ----- diversity: 0.5
# ----- Generating with seed: "ncent bump fists.
#
#                    "
# ncent bump fists.
#
#                                      JULES
#                          I never like a tucky understand.
#
#                                      VINCENT
#                               (to Pumpkin looks at him and a stoppery
#                          of the air and of the morning. It
#                          silver... that's what I that what do ya is
#                          a foot man and the store.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ncent bump fists.
#
#                    "
# ncent bump fists.
#
#                                      JULES
#                          I needs, gentlemen.
#
#                                      VINCENT
#                          And mabing couldep remammed.
#
#                He finishes a senied to same ass out of
#                          into we one... ...n't being
#                on usiss-kaps, toalhad to clemple breakfast. She
#                          little Hannin' togar.

# %% [markdown]
# > **Ex. 5.1.2**: Add a callback for Tensorboard, so you can log the training process. Start training the network (takes ~10 minutes on my computer). While it's running move on to the next question.

# %% [markdown]
# > **Ex. 5.1.3**: Answer the questions in the code above (look for code comments starting with `Q:`).

# %% [markdown]
# > **Ex. 5.1.4**: Did the network finish training? Consider the generated text across epochs.
# 1. In the early batches (0-10), the generated text looks very bad. Can you explain why the low diversity generated text contains almost only the symbol " " (that is, spaces)?
# 2. The high diversity generated text is messed up too, but in a different way. Explain how.
# 3. In later batches (20-30) what do you notice is off about the low diversity generated text?

# %% [markdown]
# > **Ex. 5.1.5**: For the network trained over all 50 epochs, generate a longer piece of text
# (say 5000 symbols long). Use the sentence `text[1486:1526]` as seed (starts with 'YOUNG MAN' ends with 'No, ')
# and set diversity to 0.5.
# Describe what features of the screenplay and language in general that the network learned in only 50 epochs.
# Also describe what serious mistakes it makes.

# %% [markdown]
# > **Ex. 5.1.6**: Do the same as above, but for 40 random letters (e.g. smash away on your keyboard) as seed. What happens? Can you explain why?

# %% [markdown]
# > **Challenge** Download [this](https://www.yelp.com/dataset/download) Yelp dataset and train a model that predicts rating given a review text!
